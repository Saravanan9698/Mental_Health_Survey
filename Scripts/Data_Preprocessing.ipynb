# %% [markdown]
# # Importing the Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import LabelEncoder
import pickle
import os

# %%
file_path = r"D:\Projects\Mini_Projects\Mental_Health_Survey\Research_Data\cleaned_data.csv"

# %%
data = pd.read_csv(file_path)

# %%
data.head(5)
# Out:
#    Gender  Age           City Working Professional or Student  \
# 0  Female   49       Ludhiana            Working Professional
# 1    Male   26       Varanasi            Working Professional
# 2    Male   33  Visakhapatnam                         Student
# 3    Male   22         Mumbai            Working Professional
# 4  Female   30         Kanpur            Working Professional
#
#           Profession  Academic Pressure  Work Pressure  CGPA  \
# 0               Chef                  0              5  0.00
# 1            Teacher                  0              4  0.00
# 2  Not Yet Disclosed                  5              0  8.97
# 3            Teacher                  0              5  0.00
# 4   Business Analyst                  0              1  0.00
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                   0                 2          6-8 hours        Healthy
# 1                   0                 3  Less than 5 hours      Unhealthy
# 2                   2                 0          5-6 hours        Healthy
# 3                   0                 1  Less than 5 hours       Moderate
# 4                   0                 1          5-6 hours      Unhealthy
#
#     Degree Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0      BHM                                    No                 1
# 1      LLB                                   Yes                 7
# 2  B.Pharm                                   Yes                 3
# 3      BBA                                   Yes                10
# 4      BBA                                   Yes                 9
#
#    Financial Stress Family History of Mental Illness  Depression
# 0                 2                               No           0
# 1                 3                               No           1
# 2                 1                               No           1
# 3                 1                              Yes           1
# 4                 4                              Yes           0

# %%
data.shape
# Out:
# (135769, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135769 entries, 0 to 135768
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Gender                                 135769 non-null  object
#  1   Age                                    135769 non-null  int64
#  2   City                                   135769 non-null  object
#  3   Working Professional or Student        135769 non-null  object
#  4   Profession                             135769 non-null  object
#  5   Academic Pressure                      135769 non-null  int64
#  6   Work Pressure                          135769 non-null  int64
#  7   CGPA                                   135769 non-null  float64
#  8   Study Satisfaction                     135769 non-null  int64
#  9   Job Satisfaction                       135769 non-null  int64
#  10  Sleep Duration                         135769 non-null  object
#  11  Dietary Habits                         135769 non-null  object
#  12  Degree                                 135769 non-null  object
#  13  Have you ever had suicidal thoughts ?  135769 non-null  object
#  14  Work/Study Hours                       135769 non-null  int64
#  15  Financial Stress                       135769 non-null  int64
#  16  Family History of Mental Illness       135769 non-null  object
#  17  Depression                             135769 non-null  int64
# dtypes: float64(1), int64(8), object(9)
# memory usage: 18.6+ MB

# %% [markdown]
# # Features Selection

# %%
numerical_features = data.select_dtypes(include = ['int64','float64'])
categorical_features = data.select_dtypes(include = 'object')

# %% [markdown]
# #

# %%
for i in numerical_features:
    plt.figure(figsize = (6,4))
    sns.kdeplot(data[i])
    print('======================================= ' + i + ' =======================================')
    plt.show()
# Out:
# ======================================= Age =======================================
# ======================================= Academic Pressure =======================================
# ======================================= Work Pressure =======================================
# ======================================= CGPA =======================================
# ======================================= Study Satisfaction =======================================
# ======================================= Job Satisfaction =======================================
# ======================================= Work/Study Hours =======================================
# ======================================= Financial Stress =======================================
# ======================================= Depression =======================================

# %%
# Correlation

corr = numerical_features.corr()

# %%
plt.figure(figsize = (14,6))

sns.heatmap(corr, cmap = 'turbo', annot = True, fmt = '.2f', linewidths = 0.5)

plt.show()

# %%
# Numerical Feature Selection

corr[abs(corr) > 0.6]
# Out:
#                     Age  Academic Pressure  Work Pressure      CGPA  \
# Age                 1.0                NaN            NaN       NaN
# Academic Pressure   NaN           1.000000      -0.617388  0.876001
# Work Pressure       NaN          -0.617388       1.000000 -0.672227
# CGPA                NaN           0.876001      -0.672227  1.000000
# Study Satisfaction  NaN           0.776152      -0.610918  0.864792
# Job Satisfaction    NaN          -0.612365            NaN -0.666749
# Work/Study Hours    NaN                NaN            NaN       NaN
# Financial Stress    NaN                NaN            NaN       NaN
# Depression          NaN                NaN            NaN       NaN
#
#                     Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# Age                                NaN               NaN               NaN
# Academic Pressure             0.776152         -0.612365               NaN
# Work Pressure                -0.610918               NaN               NaN
# CGPA                          0.864792         -0.666749               NaN
# Study Satisfaction            1.000000         -0.605938               NaN
# Job Satisfaction             -0.605938          1.000000               NaN
# Work/Study Hours                   NaN               NaN               1.0
# Financial Stress                   NaN               NaN               NaN
# Depression                         NaN               NaN               NaN
#
#                     Financial Stress  Depression
# Age                              NaN         NaN
# Academic Pressure                NaN         NaN
# Work Pressure                    NaN         NaN
# CGPA                             NaN         NaN
# Study Satisfaction               NaN         NaN
# Job Satisfaction                 NaN         NaN
# Work/Study Hours                 NaN         NaN
# Financial Stress                 1.0         NaN
# Depression                       NaN         1.0

# %%
corr.where(np.triu(np.ones(corr.shape), k = 1).astype(bool)).stack().reset_index()
# Out:
#                level_0             level_1         0
# 0                  Age   Academic Pressure -0.530250
# 1                  Age       Work Pressure  0.344741
# 2                  Age                CGPA -0.570884
# 3                  Age  Study Satisfaction -0.518355
# 4                  Age    Job Satisfaction  0.415608
# 5                  Age    Work/Study Hours -0.118010
# 6                  Age    Financial Stress -0.083578
# 7                  Age          Depression -0.564844
# 8    Academic Pressure       Work Pressure -0.617388
# 9    Academic Pressure                CGPA  0.876001
# 10   Academic Pressure  Study Satisfaction  0.776152
# 11   Academic Pressure    Job Satisfaction -0.612365
# 12   Academic Pressure    Work/Study Hours  0.122352
# 13   Academic Pressure    Financial Stress  0.076999
# 14   Academic Pressure          Depression  0.585770
# 15       Work Pressure                CGPA -0.672227
# 16       Work Pressure  Study Satisfaction -0.610918
# 17       Work Pressure    Job Satisfaction  0.449472
# 18       Work Pressure    Work/Study Hours -0.081092
# 19       Work Pressure    Financial Stress -0.020335
# 20       Work Pressure          Depression -0.258041
# 21                CGPA  Study Satisfaction  0.864792
# 22                CGPA    Job Satisfaction -0.666749
# 23                CGPA    Work/Study Hours  0.113688
# 24                CGPA    Financial Stress  0.051608
# 25                CGPA          Depression  0.511986
# 26  Study Satisfaction    Job Satisfaction -0.605938
# 27  Study Satisfaction    Work/Study Hours  0.095567
# 28  Study Satisfaction    Financial Stress  0.033063
# 29  Study Satisfaction          Depression  0.420011
# 30    Job Satisfaction    Work/Study Hours -0.098145
# 31    Job Satisfaction    Financial Stress -0.054677
# 32    Job Satisfaction          Depression -0.433394
# 33    Work/Study Hours    Financial Stress  0.036675
# 34    Work/Study Hours          Depression  0.190625
# 35    Financial Stress          Depression  0.226594

# %%
pair_corr = corr.where(np.triu(np.ones(corr.shape), k = 1).astype(bool)).stack().reset_index()

# %%
pair_corr[abs(pair_corr[0]) > 0.6]
# Out:
#                level_0             level_1         0
# 8    Academic Pressure       Work Pressure -0.617388
# 9    Academic Pressure                CGPA  0.876001
# 10   Academic Pressure  Study Satisfaction  0.776152
# 11   Academic Pressure    Job Satisfaction -0.612365
# 15       Work Pressure                CGPA -0.672227
# 16       Work Pressure  Study Satisfaction -0.610918
# 21                CGPA  Study Satisfaction  0.864792
# 22                CGPA    Job Satisfaction -0.666749
# 26  Study Satisfaction    Job Satisfaction -0.605938

# %%
corr_60 = pair_corr[abs(pair_corr[0]) > 0.6]

# %%
corr_60.columns = ['Primary','Secondary','Score']

# %%
corr_60.groupby(['Primary']).agg({
    "Secondary":'count'
}).sort_values('Secondary',ascending = False)
# Out:
#                     Secondary
# Primary
# Academic Pressure           4
# CGPA                        2
# Work Pressure               2
# Study Satisfaction          1

# %%
corr_60.groupby(['Primary']).agg({
    "Secondary":'count'
}).sort_values('Secondary',ascending = False).index
# Out:
# Index(['Academic Pressure', 'CGPA', 'Work Pressure', 'Study Satisfaction'], dtype='object', name='Primary')

# %%
col_to_drop = ['Academic Pressure', 'CGPA', 'Work Pressure', 'Study Satisfaction']

# %%
data.drop(col_to_drop, axis = 1, inplace = True)

# %%
# Categorical Feature Selection

col = []
counts = []

for i in data.select_dtypes(include = 'object').columns:
  col.append(i)
  counts.append(data[i].nunique())

# %%
pd.DataFrame({
    "col": col,
    "counts": counts
}).sort_values('counts', ascending = False)
# Out:
#                                      col  counts
# 3                             Profession      39
# 1                                   City      29
# 6                                 Degree      28
# 4                         Sleep Duration       4
# 5                         Dietary Habits       3
# 0                                 Gender       2
# 2        Working Professional or Student       2
# 7  Have you ever had suicidal thoughts ?       2
# 8       Family History of Mental Illness       2

# %%
encoders = {}
for col in categorical_features:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    encoders[col] = le

# %%
corr_1 = data.corr()

# %%
corr_1
# Out:
#                                          Gender       Age      City  \
# Gender                                 1.000000 -0.007671 -0.016664
# Age                                   -0.007671  1.000000  0.031207
# City                                  -0.016664  0.031207  1.000000
# Working Professional or Student       -0.006277  0.583934  0.016876
# Profession                             0.013445 -0.176801 -0.006316
# Job Satisfaction                      -0.009324  0.415608  0.015412
# Sleep Duration                         0.001928 -0.052529  0.008520
# Dietary Habits                         0.039256 -0.071696  0.004850
# Degree                                 0.008377  0.058084 -0.011990
# Have you ever had suicidal thoughts ? -0.010266 -0.141015  0.006614
# Work/Study Hours                       0.006896 -0.118010 -0.001199
# Financial Stress                      -0.006409 -0.083578 -0.007772
# Family History of Mental Illness      -0.015406  0.009573  0.008545
# Depression                             0.008394 -0.564844 -0.023562
#
#                                        Working Professional or Student  \
# Gender                                                       -0.006277
# Age                                                           0.583934
# City                                                          0.016876
# Working Professional or Student                               1.000000
# Profession                                                   -0.221788
# Job Satisfaction                                              0.681670
# Sleep Duration                                               -0.020130
# Dietary Habits                                               -0.052858
# Degree                                                        0.015544
# Have you ever had suicidal thoughts ?                        -0.137022
# Work/Study Hours                                             -0.116026
# Have you ever had suicidal thoughts ?                          0.009106
# Work/Study Hours                                               0.013739
# Financial Stress                                               0.004132
# Family History of Mental Illness                               1.000000
# Depression                                                     0.016165
#
#                                        Depression
# Gender                                   0.008394
# Age                                     -0.564844
# City                                    -0.023562
# Working Professional or Student         -0.520734
# Profession                               0.144660
# Job Satisfaction                        -0.433394
# Sleep Duration                           0.066894
# Dietary Habits                           0.149523
# Degree                                  -0.028861
# Have you ever had suicidal thoughts ?    0.348279
# Work/Study Hours                         0.190625
# Financial Stress                         0.226594
# Family History of Mental Illness         0.016165
# Depression                               1.000000

# %%
pair_corr_1 = corr_1.where(np.triu(np.ones(corr_1.shape), k = 1).astype(bool)).stack().reset_index()

# %%
corr_60_1 = pair_corr_1[abs(pair_corr_1[0]) > 0.6]

# %%
corr_60_1.columns = ['Primary','Secondary','Score']

# %%
corr_60_1.groupby(['Primary']).agg({
    "Secondary":'count'
}).sort_values('Secondary',ascending = False)
# Out:
#                                  Secondary
# Primary
# Working Professional or Student          1

# %%
corr_60_1.groupby(['Primary']).agg({
    "Secondary":'count'
}).sort_values('Secondary',ascending = False).index
# Out:
# Index(['Working Professional or Student'], dtype='object', name='Primary')

# %%
col_to_drop_1 = 'Working Professional or Student'

# %%
data.drop(col_to_drop_1, axis = 1, inplace = True)

# %%
# Checking For Outliers

for i in data.columns:

  print("================== ", i," ==================")
  sns.boxplot(data[i].head(10000))
  plt.show()
# Out:
# ==================  Gender  ==================
# ==================  Age  ==================
# ==================  City  ==================
# ==================  Profession  ==================
# ==================  Job Satisfaction  ==================
# ==================  Sleep Duration  ==================
# ==================  Dietary Habits  ==================
# ==================  Degree  ==================
# ==================  Have you ever had suicidal thoughts ?  ==================
# ==================  Work/Study Hours  ==================
# ==================  Financial Stress  ==================
# ==================  Family History of Mental Illness  ==================
# ==================  Depression  ==================

# %%
# Data after Preprocessing

corr_1 = data.corr()

# %%
plt.figure(figsize = (14,6))

sns.heatmap(corr_1, cmap = 'viridis', annot = True, fmt = '.2f', linewidths = 0.5)

plt.show()

# %%
data.head()
# Out:
#    Gender  Age  City  Profession  Job Satisfaction  Sleep Duration  \
# 0       0   49    15           4                 2               1
# 1       1   26    26          36                 3               2
# 2       1   33    28          28                 0               0
# 3       1   22    17          36                 1               2
# 4       0   30    12           3                 1               0
#
#    Dietary Habits  Degree  Have you ever had suicidal thoughts ?  \
# 0               0       9                                      0
# 1               2      12                                      1
# 2               0       3                                      1
# 3               1       6                                      1
# 4               2       6                                      1
#
#    Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# 0                 1                 2                                 0
# 1                 7                 3                                 0
# 2                 3                 1                                 0
# 3                10                 1                                 1
# 4                 9                 4                                 1
#
#    Depression
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0

# %%
preprocess_objects = {'encoders': encoders}

with open('D:\\Projects\\Mini_Projects\\Mental_Health_Survey\\Model\\preprocessor.pkl', 'wb') as f:
    pickle.dump(preprocess_objects, f)

# %%
data.to_csv('D:\\Projects\\Mini_Projects\\Mental_Health_Survey\\Research_Data\\preprocessed_data.csv')
